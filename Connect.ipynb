# %% [markdown]
# i am making thi shshit while not home and my fuuckign pc is not on at home so no rtx 5060, colab gpu i gotta rely on
# this notebook setups a remote ssh connection so i can coonnect to colab instance from vscode so i can run shi yay

# %%
# !mkdir -p /run/sshd
# !echo "root:ColabPassword123!" | chpasswd
# !echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config
# !echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
# !service ssh start

# 2. Download and install Ngrok
# !wget -q -O ngrok.tgz https://equinox.io
# !tar -xf ngrok.tgz
# !chmod +x ./ngrok

NGROK_TOKEN = "YOUR_NGROK_AUTHTOKEN_HERE"
import os
os.system(f"./ngrok config add-authtoken {NGROK_TOKEN}")

import subprocess
import json
import time

pipe = subprocess.Popen(["./ngrok", "tcp", "22"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(3) # Wait for tunnel to spin up

import urllib.request
with urllib.request.urlopen("http://localhost:4040/api/tunnels") as response:
    data = json.loads(response.read().decode())
    public_url = data['tunnels'][0]['public_url']
    # Parse URL to get host and port
    clean_url = public_url.replace("tcp://", "")
    host, port = clean_url.split(":")
    print("\n====== COPY THIS COMMAND FOR VS CODE ======")
    print(f"ssh root@{host} -p {port}")
    print("===========================================")
